# %%
pip install pytrends
# Out:
# Collecting pytrendsNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pytrends-4.9.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests>=2.0 in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (2.28.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (1.5.2)
# Requirement already satisfied: lxml in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\irene\appdata\roaming\python\python311\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (1.23.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\irene\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (2022.12.7)
# Requirement already satisfied: six>=1.5 in c:\users\irene\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.0
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# WHOLE CODE IN A SINGLE CELL TO SAVE TIME ON EXECUTION
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

trends = TrendReq()
search_term = str(input("What search term are you looking for?   "))



trends.build_payload(kw_list=[search_term])

data = trends.interest_by_region()
# data = trends    # CHECK FOR OTHER DEFAULT .interest_by_XXXXXXX as there are multiple options to explore

data = data.sort_values(by=search_term, ascending=False)
data = data.head(10)
print(data)



data.reset_index().plot(x="geoName",
                        y=search_term,
                        figsize=(15,12),
                        kind="bar")
plt.style.use("fivethirtyeight")
plt.show()



data = TrendReq(hl="en-US", tz=360)
data.build_payload(kw_list=[search_term])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15,12))
data[search_term].plot()
plt.style.use("fivethirtyeight")
plt.title(f"Total Google Searches for {search_term}",
          fontweight="bold")
plt.xlabel("Year")
plt.ylabel("Total Count")
plt.show()
# Out:
#            Data Science
# geoName
# Singapore           100
# India                98
# Ethiopia             98
# China                97
# Nigeria              83
# Kenya                74
# Pakistan             67
# Ghana                66
# Nepal                64
# Sri Lanka            53

# %% [markdown]
# PIECES OF CODE SPLIT INTO CELLS

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

trends = TrendReq()
search_term = str(input("What search term are you looking for?   "))

# %%
trends.build_payload(kw_list=[search_term])

data = trends.interest_by_region()
# data = trends    # CHECK FOR OTHER DEFAULT .interest_by_XXXXXXX as there are multiple options to explore

data = data.sort_values(by=search_term, ascending=False)
data = data.head(10)
print(data)
# Out:
#               Love
# geoName
# Zambia         100
# Ghana          100
# Nigeria         96
# Uganda          91
# Philippines     75
# Tanzania        61
# Sri Lanka       59
# Nepal           54
# Kenya           52
# South Africa    51

# %%
data.reset_index().plot(x="geoName",
                        y=search_term,
                        figsize=(15,12),
                        kind="bar")
plt.style.use("fivethirtyeight")
plt.show()

# %%
data = TrendReq(hl="en-US", tz=360)
data.build_payload(kw_list=[search_term])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15,12))
data[search_term].plot()
plt.style.use("fivethirtyeight")
plt.title(f"Total Google Searches for {search_term}",
          fontweight="bold")
plt.xlabel("Year")
plt.ylabel("Total Count")
plt.show()
